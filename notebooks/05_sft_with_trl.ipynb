# %% [markdown]
# # Supervised Fine-Tuning with TRL — Week 5
#
# ## Learning Objectives
# By the end of this notebook you will be able to:
# 1. Describe where SFT sits in the modern LLM training pipeline
# 2. Load a synthetic dataset and convert it to HuggingFace Dataset format
# 3. Run a smoke-test SFT training run using `SFTRunner` with LoRA
# 4. Generate text from your fine-tuned adapter and compare it to the base model
# 5. Explain the risk of overfitting on small datasets
#
# ## Time Estimate
# ~35 minutes (10 min setup + 15 min training + 10 min eval)

# %%
import sys, importlib, json, os
sys.path.insert(0, '..')

from dotenv import load_dotenv
load_dotenv(override=True)

# %matplotlib inline
import matplotlib.pyplot as plt

import src.sft_trainer as sft_trainer_mod
import src.lora_setup as lora_setup
importlib.reload(sft_trainer_mod)
importlib.reload(lora_setup)

from src.sft_trainer import SFTRunner
from src.lora_setup import build_lora_config
from src.config import FINETUNE_BACKEND, BASE_MODEL_HF
from src.cost_tracker import CostTracker
from src.utils import append_to_reflection

tracker = CostTracker()
print(f"Backend : {FINETUNE_BACKEND}")
print(f"Model   : {BASE_MODEL_HF}")
# Out:
# Backend : hf
# Model   : Qwen/Qwen2.5-0.5B-Instruct

# %% [markdown]
# ---
# ## Part 1: The nanochat Pipeline in 5 Minutes
#
# Andrej Karpathy's **nanochat** (Oct 2025) is the clearest description of the full modern LLM training pipeline:
#
# ```
# Raw text corpus
#       │
#       ▼
#   Tokenizer  (BPE / SentencePiece — builds vocabulary)
#       │
#       ▼
#   Pretraining  (next-token prediction on billions of tokens — base model)
#       │
#       ▼
#   Mid-training  (domain-specific corpus, long context, math/code upweighting)
#       │
#       ▼
# >>> [WE ARE HERE] Supervised Fine-Tuning — SFT <<<
#   (teach the model to follow instructions by imitating high-quality examples)
#       │
#       ▼
#   Preference RL  (GRPO / DPO / KTO — align with human preferences)
#       │
#       ▼
#   Evaluation  (benchmarks, vibe checks, red-teaming)
#       │
#       ▼
#   Serve  (quantize, deploy, monitor)
# ```
#
# **We skip pretrain and mid-train** because we start from `Qwen2.5-0.5B-Instruct`, which Alibaba has already pretrained and mid-trained. Our job is SFT: teach it to answer questions about *your* resume domain in the style you want.
#
# **What makes SFT data good?**
# - Each example is `(instruction, [context], response)` — the model learns to complete the response given the instruction
# - Quality >> quantity: 500 carefully written examples beats 50,000 scraped ones
# - Diversity: cover the range of queries the model will see in production
# - Consistency: if different examples contradict each other, the model gets confused

# %% [markdown]
# ---
# ## Part 2: Loading the Dataset
#
# We'll load the synthetic dataset generated in Notebook 03. If it doesn't exist yet, we fall back to 5 hardcoded examples so the rest of the notebook runs.

# %%
# Load synthetic dataset or fallback
DATASET_PATH = '../outputs/synthetic_dataset.json'


FALLBACK_EXAMPLES = [
    {
        "instruction": "What is Scott's background in machine learning?",
        "response": (
            "Scott has extensive experience in machine learning, including supervised learning, "
            "deep learning with PyTorch and TensorFlow, and NLP. He has worked on production ML "
            "systems and is currently studying ML Engineering with a focus on LLM fine-tuning."
        )
    },
    {
        "instruction": "What programming languages does Scott know?",
        "response": (
            "Scott is proficient in Python, TypeScript, and SQL. He uses Python for all ML/data work "
            "and TypeScript for full-stack applications. He also has experience with bash scripting "
            "for DevOps workflows."
        )
    },
    {
        "instruction": "What are Scott's most recent projects?",
        "response": (
            "Scott's most recent projects include building a RAG system with FAISS and contextual "
            "retrieval (Week 4 homework), a multi-agent framework using Claude's API, and this "
            "Week 5 LLM fine-tuning pipeline using LoRA and TRL."
        )
    },
    {
        "instruction": "What is Scott's educational background?",
        "response": (
            "Scott holds a degree in a quantitative field and is currently enrolled in an ML Engineering "
            "course focused on building production-grade LLM systems, covering RAG, fine-tuning, "
            "preference tuning, and deployment."
        )
    },
    {
        "instruction": "How would you describe Scott's approach to problem-solving?",
        "response": (
            "Scott takes a systematic, first-principles approach: he starts by understanding the "
            "problem deeply, then selects the simplest solution that works, and iterates empirically. "
            "He values clean code, reproducible experiments, and clear documentation."
        )
    },
]

# data = [json.loads(line) for line in open("your_file.jsonl", "r", encoding="utf-8") if line.strip()]
raw_data=[]
if os.path.exists(DATASET_PATH):

    # with open(DATASET_PATH, 'r') as f:
    with open(DATASET_PATH, "r", encoding="utf-8") as f:
        # raw_data = [json.loads(f) for f in open("your_file.jsonl", "r", encoding="utf-8") if f.strip()]#json.load(f)
        raw_data = [json.loads(line) for line in f if line.strip()]
    print(f"Loaded {len(raw_data)} examples from {DATASET_PATH}")
else:
    raw_data = FALLBACK_EXAMPLES
    print(f"Dataset file not found. Using {len(raw_data)} fallback examples.")
    print(f"Run Notebook 03 first to generate a full synthetic dataset.")
print(raw_data)
# Show a sample record
print("\n--- Sample record ---")
sample = raw_data[0]


print(f"Instruction: {sample.get('instruction', sample.get('prompt', '?'))}")
response_key = 'response' if 'response' in sample else 'output'
print(f"Response   : {sample.get(response_key, '?')[:200]}...")


# print(sample.get('instruction'))
# # print(f"Instruction: {sample.get('messages', [{}])[1].get('content', '?')}")
# # print(f"Instruction: {sample[0].get('instruction','') .get('response', '?')}")
# response_key = 'content' if 'content' in sample.get('messages', [{}])[2].get('content', '?') else 'output'
# print(f"Response   : {sample.get('messages', [{}])[2].get('content', '?')[:200]}...")
# Out:
# Dataset file not found. Using 5 fallback examples.
# Run Notebook 03 first to generate a full synthetic dataset.
# [{'instruction': "What is Scott's background in machine learning?", 'response': 'Scott has extensive experience in machine learning, including supervised learning, deep learning with PyTorch and TensorFlow, and NLP. He has worked on production ML systems and is currently studying ML Engineering with a focus on LLM fine-tuning.'}, {'instruction': 'What programming languages does Scott know?', 'response': 'Scott is proficient in Python, TypeScript, and SQL. He uses Python for all ML/data work and TypeScript for full-stack applications. He also has experience with bash scripting for DevOps workflows.'}, {'instruction': "What are Scott's most recent projects?", 'response': "Scott's most recent projects include building a RAG system with FAISS and contextual retrieval (Week 4 homework), a multi-agent framework using Claude's API, and this Week 5 LLM fine-tuning pipeline using LoRA and TRL."}, {'instruction': "What is Scott's educational background?", 'response': 'Scott holds a degree in a quantitative field and is currently enrolled in an ML Engineering course focused on building production-grade LLM systems, covering RAG, fine-tuning, preference tuning, and deployment.'}, {'instruction': "How would you describe Scott's approach to problem-solving?", 'response': 'Scott takes a systematic, first-principles approach: he starts by understanding the problem deeply, then selects the simplest solution that works, and iterates empirically. He values clean code, reproducible experiments, and clear documentation.'}]
#
# --- Sample record ---
# Instruction: What is Scott's background in machine learning?
# Response   : Scott has extensive experience in machine learning, including supervised learning, deep learning with PyTorch and TensorFlow, and NLP. He has worked on production ML systems and is currently studying ...

# %%
# Old version

# Convert to HuggingFace Dataset format
# TRL SFTTrainer expects a 'text' field with the full formatted prompt+response

from datasets import Dataset

# def format_example(ex, tokenizer):
def format_example(ex: dict) -> dict:
    messages = ex.get("messages", [])
    # Extract roles safely
    system_msg = next(
        (m["content"] for m in messages if m["role"] == "system"),
        "You are a helpful assistant."
    )

    user_msg = next(
        (m["content"] for m in messages if m["role"] == "user"),
        ""
    )

    assistant_msg = next(
        (m["content"] for m in messages if m["role"] == "assistant"),
        ""
    )

    text = (
        f"<|im_start|>system\n{system_msg}<|im_end|>\n"
        f"<|im_start|>user\n{user_msg}<|im_end|>\n"
        f"<|im_start|>assistant\n{assistant_msg}<|im_end|>"
    )

    return {"text": text}



formatted = [format_example(ex) for ex in raw_data]

train_dataset = Dataset.from_list(formatted)



print(f"Dataset size: {len(train_dataset)} examples")
print("\nFormatted example (first 400 chars):")
print(train_dataset[1]["text"][:400])
# Out:
# Dataset size: 5 examples
#
# Formatted example (first 400 chars):
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|im_end|>
# <|im_start|>assistant
# <|im_end|>

# %%
from datasets import Dataset

def format_example(ex: dict) -> dict:
    """Format a raw example into the chat template expected by Qwen2.5-Instruct."""
    instruction = ex.get('instruction') or ex.get('prompt') or ''
    response = ex.get('response') or ex.get('output') or ex.get('answer') or ''
    text = (
        f"<|im_start|>system\nYou are a helpful assistant that answers questions about Scott's background.<|im_end|>\n"
        f"<|im_start|>user\n{instruction}<|im_end|>\n"
        f"<|im_start|>assistant\n{response}<|im_end|>"
    )
    return {'text': text}

formatted = [format_example(ex) for ex in raw_data]
train_dataset = Dataset.from_list(formatted)

print(f"Dataset size: {len(train_dataset)} examples")
print(f"\nFormatted example (first 400 chars):")
print(train_dataset[0]['text'][:400])
# Out:
# Dataset size: 5 examples
#
# Formatted example (first 400 chars):
# <|im_start|>system
# You are a helpful assistant that answers questions about Scott's background.<|im_end|>
# <|im_start|>user
# What is Scott's background in machine learning?<|im_end|>
# <|im_start|>assistant
# Scott has extensive experience in machine learning, including supervised learning, deep learning with PyTorch and TensorFlow, and NLP. He has worked on production ML systems and is currently studyi

# %% [markdown]
# ---
# ## Part 3: Running SFT
#
# We'll run a **smoke-test** training with `max_steps=20`. This is just enough to verify that:
# 1. The model loads correctly
# 2. The LoRA adapters are applied
# 3. The training loop runs without errors
# 4. The loss decreases (even if only slightly)
#
# **For real training** on a resume Q&A dataset you'd use `num_epochs=3` and drop `max_steps` (or set it to -1).
#
# Training time estimates:
# - Mac M3 (MLX backend, 50 examples): ~5-10 minutes for 3 epochs
# - GPU 8GB (HF backend, 50 examples, 4-bit): ~3-5 minutes for 3 epochs
# - Smoke test (20 steps): ~1-2 minutes on either backend

# %%
from src.sft_trainer import SFTRunner
from src.lora_setup import build_lora_config

lora_cfg = build_lora_config(rank=8, alpha=16, variant='vanilla')

runner = SFTRunner(backend=FINETUNE_BACKEND, base_model=BASE_MODEL_HF)

results = runner.train(
    dataset=train_dataset,
    lora_config=lora_cfg,
    output_dir='../outputs/sft_adapter',
    max_steps=20,          # smoke test — students extend to num_epochs=3
    per_device_batch_size=2,
    gradient_accumulation_steps=4,
    max_seq_length=512,
    use_4bit=True,
)

print("\nTraining results:")
print(results)

train_loss = results.get('train_loss', float('nan'))
print(f"\nFinal training loss: {train_loss:.4f}")
print("Adapter saved to: outputs/sft_adapter/")
# Out:
# [lora_setup] LoraConfig built:
#   variant         : vanilla
#   rank (r)        : 8
#   alpha           : 16
#   lora_dropout    : 0.05
#   target_modules  : ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj']
#   task_type       : CAUSAL_LM
#   use_rslora      : False
#   use_dora        : False
#   init_lora_weights: True
# [sft_trainer] Initialized SFTRunner backend=mlx model=Qwen/Qwen2.5-0.5B-Instruct
# [sft_trainer] Starting training: backend=mlx, epochs=3, max_steps=20
# [sft_trainer] Output directory: ../outputs/sft_adapter
# [sft_trainer] MLX backend selected
# [sft_trainer] Wrote 5 messages-format records to ../outputs/sft_adapter/mlx_data/train.jsonl
# [sft_trainer] Using mlx_lm Python API for training
# Loading configuration file ../outputs/sft_adapter/_mlx_lora_train_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading datasets
# Warning: Validation set not found or empty. Training will proceed without validation.
# Training
# Trainable parameters: 0.594% (2.933M/494.033M)
# Starting training..., iters: 20
# Iter 10: Train loss 1.037, Learning Rate 1.000e-04, It/sec 8.558, Tokens/sec 804.441, Trained Tokens 940, Peak mem 1.638 GB
# Iter 20: Train loss 0.009, Learning Rate 1.000e-04, It/sec 12.116, Tokens/sec 1138.926, Trained Tokens 1880, Peak mem 1.638 GB
# Saved final weights to ../outputs/sft_adapter/adapters.safetensors.
# [sft_trainer] MLX training complete, adapter at ../outputs/sft_adapter
#
# Training results:
# {'train_loss': nan, 'steps': 20, 'adapter_path': '../outputs/sft_adapter'}
#
# Final training loss: nan
# Adapter saved to: outputs/sft_adapter/

# %%
from src.sft_trainer import SFTRunner
from src.lora_setup import build_lora_config

lora_cfg = build_lora_config(rank=8, alpha=16, variant='vanilla')

runner = SFTRunner(backend=FINETUNE_BACKEND, base_model=BASE_MODEL_HF)

results = runner.train(
    dataset=train_dataset,
    lora_config=lora_cfg,
    output_dir='../outputs/sft_adapter',
    max_steps=20,          # smoke test — students extend to num_epochs=3
    per_device_batch_size=2,
    gradient_accumulation_steps=4,
    # max_seq_length=512,
    use_4bit=True,
)

print("\nTraining results:")
print(results)

train_loss = results.get('train_loss', float('nan'))
print(f"\nFinal training loss: {train_loss:.4f}")
print("Adapter saved to: outputs/sft_adapter/")
# Out:
# [lora_setup] LoraConfig built:
#   variant         : vanilla
#   rank (r)        : 8
#   alpha           : 16
#   lora_dropout    : 0.05
#   target_modules  : ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj']
#   task_type       : CAUSAL_LM
#   use_rslora      : False
#   use_dora        : False
#   init_lora_weights: True
# [sft_trainer] Initialized SFTRunner backend=hf model=Qwen/Qwen2.5-0.5B-Instruct
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5
#       6 runner = SFTRunner(backend=FINETUNE_BACKEND, base_model=BASE_MODEL_HF)
#       7
#       8 results = runner.train(
# ----> 9     dataset=train_dataset,
#      10     lora_config=lora_cfg,
#      11     output_dir='../outputs/sft_adapter',
#      12     max_steps=20,          # smoke test — students extend to num_epochs=3
#
# NameError: name 'train_dataset' is not defined

# %%
from src.sft_trainer import SFTRunner
from src.lora_setup import build_lora_config

lora_cfg = build_lora_config(rank=8, alpha=16, variant='vanilla')

runner = SFTRunner(backend=FINETUNE_BACKEND, base_model=BASE_MODEL_HF)

results = runner.train(
    dataset=train_dataset,
    lora_config=lora_cfg,
    output_dir='../outputs/sft_adapter',
    max_steps=20,          # smoke test — students extend to num_epochs=3
    per_device_batch_size=2,
    gradient_accumulation_steps=4,
    # max_seq_length=512,
    use_4bit=True,
)

print("\nTraining results:")
print(results)

train_loss = results.get('train_loss', float('nan'))
print(f"\nFinal training loss: {train_loss:.4f}")
print("Adapter saved to: outputs/sft_adapter/")
# Out:
# [lora_setup] LoraConfig built:
#   variant         : vanilla
#   rank (r)        : 8
#   alpha           : 16
#   lora_dropout    : 0.05
#   target_modules  : ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj']
#   task_type       : CAUSAL_LM
#   use_rslora      : False
#   use_dora        : False
#   init_lora_weights: True
# [sft_trainer] Initialized SFTRunner backend=hf model=Qwen/Qwen2.5-0.5B-Instruct
# [sft_trainer] Starting training: backend=hf, epochs=3, max_steps=20
# [sft_trainer] Output directory: ../outputs/sft_adapter
# [sft_trainer] Loading HF/TRL dependencies...
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/kernels/utils.py:391: FutureWarning: Future versions of `kernels` (>=0.15) will require specifying a kernel version or revision. See: https://huggingface.co/docs/kernels/migration
#   revision = select_revision_or_version(repo_id, revision=revision, version=version)
# Failed to load CPU gemm_4bit_forward from kernels-community: 404 Client Error. (Request ID: Root=1-6a099c02-67ed0db56c0c768f304adfc7;5ca14ac8-4195-4f78-af6d-d7cf398c8934)
#
# Repository Not Found for url: https://huggingface.co/api/kernels/kernels-community/quantization_bitsandbytes/tree/main/build?recursive=false&expand=false.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.
# For more details, see https://huggingface.co/docs/huggingface_hub/authentication. Please make sure you already `pip install kernels` and the kernels >= 0.11.1
# [sft_trainer] 4-bit QLoRA enabled
# [sft_trainer] Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/default/ops.py:223: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:36: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [sft_trainer] Base model and tokenizer loaded
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# trainable params: 4,399,104 || all params: 498,431,872 || trainable%: 0.8826
# [sft_trainer] Starting SFTTrainer training loop...
# Adding EOS to train dataset:   0%|          | 0/5 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/5 [00:00<?, ? examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 08:03, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.025282</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.136725</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:80: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# /home/chris/Homework5-Submission/.venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [sft_trainer] Training complete: loss=2.5810, steps=20
# [sft_trainer] Adapter saved to ../outputs/sft_adapter
#
# Training results:
# {'train_loss': 2.581003475189209, 'steps': 20, 'adapter_path': '../outputs/sft_adapter'}
#
# Final training loss: 2.5810
# Adapter saved to: outputs/sft_adapter/

# %% [markdown]
# ---
# ## Part 4: Evaluating the Fine-Tuned Model
#
# After training, we can run quick inference to see if the adapter changed the model's behavior. We compare:
# 1. **Tuned model**: loaded with the LoRA adapter from `outputs/sft_adapter`
# 2. **Base model baseline** (from memory — what the model said before fine-tuning)
#
# With only 20 steps on 5 examples, don't expect dramatic improvements. The point is to verify the pipeline works end-to-end.

# %%
# Quick inference with the fine-tuned adapter
TEST_PROMPT = "What is Scott's background in machine learning?"

print(f"Prompt: {TEST_PROMPT}")
print("=" * 60)
print("Fine-tuned model response:")

tuned_response = runner.generate(TEST_PROMPT, max_new_tokens=200)
print(tuned_response)

print()
print("(Base model response would be more generic — it doesn't know 'Scott')")
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Prompt: What is Scott's background in machine learning?
# ============================================================
# Fine-tuned model response:
# [sft_trainer] No model in memory. Loading from adapter path...
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# [sft_trainer] Generating response for prompt: What is Scott's background in machine learning?...
# [sft_trainer] Generation complete (1123 chars)
#  As an AI language model, I do not have access to information about your specific situation. However, typically, a person's background in machine learning can include:
#
# 1. Education: The person may have completed a degree in computer science, data science, or related fields.
#
# 2. Work experience: The person may have worked as a software developer, data analyst, or other position that required knowledge of machine learning algorithms and techniques.
#
# 3. Internship or internship: If the person has gained hands-on experience working with machine learning tools and frameworks, this could be their background.
#
# 4. Research or consulting work: The person may have conducted research projects or contributed to consulting firms that use machine learning technologies for their clients' business needs.
#
# 5. Academic publications: The person may have published papers on topics related to machine learning, which demonstrates their expertise in the field.
#
# It's worth noting that the specific background of someone using machine learning will depend on their individual career path and goals. It's important to understand what
#
# (Base model response would be more generic — it doesn't know 'Scott')

# %%
# Quick inference with the fine-tuned adapter
TEST_PROMPT = "What is Scott's background in machine learning?"

print(f"Prompt: {TEST_PROMPT}")
print("=" * 60)
print("Fine-tuned model response:")

tuned_response = runner.generate(TEST_PROMPT, max_new_tokens=200)
print(tuned_response)

print()
print("(Base model response would be more generic — it doesn't know 'Scott')")
# Out:
# Prompt: What is Scott's background in machine learning?
# ============================================================
# Fine-tuned model response:
# [sft_trainer] Loading MLX model for inference from ../outputs/sft_adapter
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# [sft_trainer] MLX generation complete (988 chars)
# Scott has extensive experience in machine learning, including supervised learning, deep learning with PyTorch and TensorFlow, and NLP. He has worked on production ML systems and is currently studying ML Engineering with a focus on LLM fine-tuning.  Scott has worked on production ML systems and is currently studying ML Engineering with a focus on LLM fine-tuning.  Scott has worked on production ML systems and is currently studying ML Engineering with a focus on LLM fine-tuning.  Scott has extensive experience in production ML, including RAG, fine-tuning, preference tuning, and deployment. He has worked on production ML systems and is currently studying ML Engineering with a focus on LLM fine-tuning.  Scott has experience in production ML, including RAG, fine-tuning, preference tuning, and deployment. He has worked on production ML systems and is currently studying ML Engineering with a focus on LLM fine-tuning.  Scott has extensive experience in production ML, including RAG,
#
# (Base model response would be more generic — it doesn't know 'Scott')

# %%
# Quick inference with the fine-tuned adapter
TEST_PROMPT = "What was Giulia's role and tenure at Knewton, and what key contributions did she make there?"

print(f"Prompt: {TEST_PROMPT}")
print("=" * 60)
print("Fine-tuned model response:")

tuned_response = runner.generate(TEST_PROMPT, max_new_tokens=200)
print(tuned_response)

print()
print("(Base model response would be more generic — it doesn't know 'Scott')")
# Out:
# Prompt: What was Giulia's role and tenure at Knewton, and what key contributions did she make there?
# ============================================================
# Fine-tuned model response:
# [sft_trainer] Generating response for prompt: What was Giulia's role and tenure at Knewton, and what key contributions did she...
# [sft_trainer] Generation complete (706 chars)
#  I Italiasystemernaаратsystem汉族арамбал奴隶系统老龄化олодаратrosseаратioneаратiloameаратadear倫lokарат�erde奴隶奴隶�аратаратаратаратamansteamatown奴隶系统аратаратаратарат统一两手аратаратаратilli�奴隶系统汉族ulanаратsystemаратарат奴隶系统汉族AMEAZaron奴隶奴隶骨ulleарат系统系统ionарат奴隶系统 financier奴隶�аратаратаратsourceарат系统系统ameaqueаратарат矣аратаратsystemsystemарамаратsystemsарат奴隶�aller矻аратаратiloerna倫�аратаратаратарамsystemame�壞ardenаратboneарат�ulanаратарат rougesourcesiodeарат系统аратаратаратаратаратamelаратаратарамsystemаратаратаратаратарат�арат系统аратsystemulanаратsystemаратаратlacsystemame mobarieаратаратарат汉族аратаратарат系统ilonарат汉族�арат�аратарат系统аратimoreаратаратаратаратаратsystemарат�奴隶аратsystemame�аратаратsystemаратаратарат系统系统
#
# (Base model response would be more generic — it doesn't know 'Scott')

# %%
# Plot training loss if available (TRL logs it in trainer.state.log_history)
training_losses = []

# Try to read loss from the trainer log file if it was saved
trainer_log_path = '../outputs/sft_adapter/trainer_state.json'
if os.path.exists(trainer_log_path):
    with open(trainer_log_path, 'r') as f:
        trainer_state = json.load(f)
    log_history = trainer_state.get('log_history', [])
    training_losses = [entry['loss'] for entry in log_history if 'loss' in entry]
    print(f"Found {len(training_losses)} loss values in trainer log")
else:
    # Synthetic placeholder — replace with real values after training
    training_losses = [2.4, 2.1, 1.9, 1.75, 1.65, 1.58, 1.52, 1.48, 1.45, 1.42]
    print("No trainer log found. Using placeholder loss curve.")

if training_losses:
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.plot(range(1, len(training_losses) + 1), training_losses, marker='o', linewidth=2, color='steelblue')
    ax.set_xlabel('Logging Step')
    ax.set_ylabel('Training Loss')
    ax.set_title('SFT Training Loss Curve (Qwen-0.5B + LoRA r=8)')
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    os.makedirs('../outputs', exist_ok=True)
    plt.savefig('../outputs/sft_loss_curve.png', dpi=120)
    plt.show()
    print("Loss curve saved to outputs/sft_loss_curve.png")
# Out:
# No trainer log found. Using placeholder loss curve.
# Loss curve saved to outputs/sft_loss_curve.png

# %%
# Plot training loss if available (TRL logs it in trainer.state.log_history)
training_losses = []

# Try to read loss from the trainer log file if it was saved
trainer_log_path = '../outputs/sft_adapter/trainer_state.json'
if os.path.exists(trainer_log_path):
    with open(trainer_log_path, 'r') as f:
        trainer_state = json.load(f)
    log_history = trainer_state.get('log_history', [])
    training_losses = [entry['loss'] for entry in log_history if 'loss' in entry]
    print(f"Found {len(training_losses)} loss values in trainer log")
else:
    # Synthetic placeholder — replace with real values after training
    training_losses = [2.4, 2.1, 1.9, 1.75, 1.65, 1.58, 1.52, 1.48, 1.45, 1.42]
    print("No trainer log found. Using placeholder loss curve.")

if training_losses:
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.plot(range(1, len(training_losses) + 1), training_losses, marker='o', linewidth=2, color='steelblue')
    ax.set_xlabel('Logging Step')
    ax.set_ylabel('Training Loss')
    ax.set_title('SFT Training Loss Curve (Qwen-0.5B + LoRA r=8)')
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    os.makedirs('../outputs', exist_ok=True)
    plt.savefig('../outputs/sft_loss_curve.png', dpi=120)
    plt.show()
    print("Loss curve saved to outputs/sft_loss_curve.png")
# Out:
# No trainer log found. Using placeholder loss curve.
# Loss curve saved to outputs/sft_loss_curve.png

# %% [markdown]
# ### TODO 1: Extend the Smoke Test
#
# Change `max_steps` from 20 to 50 in the training cell above and re-run.
#
# In the cell below, record what you observe and answer:
# - Does the loss decrease further between step 20 and step 50?
# - Is the decrease steady or does it plateau?
# - What does this tell you about whether 20 steps was enough?

# %%
# TODO 1: Record your observations after running with max_steps=50
todo1_response = """


Loss at step 20: 2.581
Loss at step 50: 2.319


Observation: Does the loss decrease between step 20 and 50?
Yes, it descreased. 

What does this tell you about convergence at 20 steps?
 Well, it means how much the model has started stabilizing and learning useful patterns.
"""
print(todo1_response)
# Out:
# Loss at step 20: 2.581
# Loss at step 50: 2.319
#
#
# Observation: Does the loss decrease between step 20 and 50?
# Yes, it descreased.
#
# What does this tell you about convergence at 20 steps?
#  Well, it means how much the model has started stabilizing and learning useful patterns.

# %%
# TODO 1 reflection -- edit your answer below, then run this cell.
todo1_reflection = """[Replace with your answer to TODO 1: extend max_steps from 20 to 50 and observe]

Loss at step 50: 2.319

and the loss descreased. 
It means the model  was still learning.

Hint: After re-running training with max_steps=50, record the final loss at step 20 and at
step 50, then say in 2-3 sentences whether the loss kept dropping steadily, plateaued, or
got noisier. Conclude whether 20 steps was enough for this synthetic dataset and what
that implies for choosing max_steps in real runs.
"""
print(todo1_reflection)
# Out:
# [Replace with your answer to TODO 1: extend max_steps from 20 to 50 and observe]
#
# Loss at step 50: 2.319
#
# and the loss descreased.
# It means the model  was still learning.
#
# Hint: After re-running training with max_steps=50, record the final loss at step 20 and at
# step 50, then say in 2-3 sentences whether the loss kept dropping steadily, plateaued, or
# got noisier. Conclude whether 20 steps was enough for this synthetic dataset and what
# that implies for choosing max_steps in real runs.

# %% [markdown]
# ### TODO 2: Overfitting Risk
#
# You have a dataset of 50 synthetic Q&A pairs. You train for 10 epochs.
#
# In 2-3 sentences, explain:
# - What is overfitting in the context of SFT?
# - Why is it especially dangerous when the dataset is small?
# - What practical symptoms would you see in the model's outputs?

# %%
# TODO 2: Answer in 2-3 sentences
todo2_response = """


Overfitting in SFT means ...
Overfitting in SFT means the model has learned the training examples too narrowly 
and memorized them instead of learning to generalize.
 In practice, it will do well on the exact training Q&A pairs
  but fail on new or slightly different prompts, 
  often repeating answers verbatim or hallucinating training-only facts.

With a small dataset it's dangerous because ...
With a small dataset it’s dangerous because the model sees the same few examples over and over, 
so it memorizes them instead of learning to answer new questions.
 That makes it brittle and likely to fail on slightly different prompts.

Practical symptoms include ...
Practical symptoms include:
- repeating training answers word-for-word
- failing on slightly rephrased questions
- giving overly specific or wrong details from the training set
- hallucinating facts that only appeared in the training examples.


"""
print(todo2_response)
# Out:
# Overfitting in SFT means ...
# Overfitting in SFT means the model has learned the training examples too narrowly
# and memorized them instead of learning to generalize.
#  In practice, it will do well on the exact training Q&A pairs
#   but fail on new or slightly different prompts,
#   often repeating answers verbatim or hallucinating training-only facts.
#
# With a small dataset it's dangerous because ...
# With a small dataset it’s dangerous because the model sees the same few examples over and over,
# so it memorizes them instead of learning to answer new questions.
#  That makes it brittle and likely to fail on slightly different prompts.
#
# Practical symptoms include ...
# Practical symptoms include:
# - repeating training answers word-for-word
# - failing on slightly rephrased questions
# - giving overly specific or wrong details from the training set
# - hallucinating facts that only appeared in the training examples.

# %%
# TODO 2 reflection -- edit your answer below, then run this cell.
todo2_reflection = """[Replace with your answer to TODO 2: overfitting risk on 50 Q&A pairs x 10 epochs]

With 50 Q&A pairs trained for 10 epochs, the risk is that the model will 
memorize those exact pairs instead of learning to generalize.
 It will likely give correct answers only for the training prompts,
  but fail or hallucinate on new or slightly different questions.

Hint: In 2-3 sentences define overfitting in the SFT context (model memorizes the training
pairs instead of generalizing), explain why a 50-pair dataset trained 10 epochs makes this
acutely dangerous (each pair is seen 10x, low data diversity), and list 2 practical symptoms
you would expect (e.g., verbatim regurgitation of training answers, brittleness on slight
prompt rephrasings, hallucinating training-only facts).
"""
print(todo2_reflection)
# Out:
# [Replace with your answer to TODO 2: overfitting risk on 50 Q&A pairs x 10 epochs]
#
# With 50 Q&A pairs trained for 10 epochs, the risk is that the model will
# memorize those exact pairs instead of learning to generalize.
#  It will likely give correct answers only for the training prompts,
#   but fail or hallucinate on new or slightly different questions.
#
# Hint: In 2-3 sentences define overfitting in the SFT context (model memorizes the training
# pairs instead of generalizing), explain why a 50-pair dataset trained 10 epochs makes this
# acutely dangerous (each pair is seen 10x, low data diversity), and list 2 practical symptoms
# you would expect (e.g., verbatim regurgitation of training answers, brittleness on slight
# prompt rephrasings, hallucinating training-only facts).

# %% [markdown]
# ---
# ## Summary
#
# In this notebook you:
# - Mapped SFT's position in the full nanochat training pipeline
# - Loaded a synthetic Q&A dataset and formatted it for TRL's SFTTrainer
# - Ran a smoke-test SFT training (20 steps) with LoRA r=8
# - Generated text from the fine-tuned adapter and plotted the loss curve
#
# **Key takeaways:**
# - `max_steps=20` is a sanity check — increase to `num_epochs=3` for real training
# - The adapter adds ~0.4% parameters (r=8) and trains in minutes on a laptop
# - Overfitting on small datasets is the #1 failure mode in SFT
#
# Next: `06_preference_tuning.ipynb` — making the model not just capable, but *aligned*.

# %%
# Build reflection from student TODO answers (auto-captured)
section_text = (
    "### TODO 1: Extend the Smoke Test (max_steps=50)\n" + (todo1_reflection if 'todo1_reflection' in dir() else "[not completed]") + "\n\n" +
    "### TODO 2: Overfitting Risk\n" + (todo2_reflection if 'todo2_reflection' in dir() else "[not completed]")
)
append_to_reflection(
    notebook="05",
    section_title="Supervised Fine-Tuning with TRL",
    reflection_content=section_text,
    output_dir="../outputs",
)
print("Reflection auto-saved to outputs/homework_reflection.md")
tracker.report()
# Out:
# Reflection auto-saved to outputs/homework_reflection.md
# ============================================================
# API COST REPORT
# ============================================================
# Total API calls:     0
# Total input tokens:  0
# Total output tokens: 0
# Total cost:          $0.0000
#
# ============================================================
